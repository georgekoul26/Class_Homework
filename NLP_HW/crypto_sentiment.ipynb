# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi.newsapi_client import NewsApiClient
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv('NEWS_API_KEY')

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
headlines_btc = newsapi.get_everything(
    q='bitcoin OR BTC',
    language='en',
    page_size=100,
    sort_by='relevancy'
)
print(f"Total Results: {headlines_btc['totalResults']}")
# Out:
# Total Results: 8451

# %%
# Fetch the Ethereum news articles
headlines_eth = newsapi.get_everything(
    q='ethereum OR ETH',
    language='en',
    page_size=100,
    sort_by='relevancy'
)
print(f"Total Results: {headlines_eth['totalResults']}")
headlines_eth["articles"][0]
# Out:
# Total Results: 3110
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Adi Robertson',
#  'title': 'India will reportedly introduce bill to make owning cryptocurrency illegal',
#  'description': 'India’s legislature is reportedly considering a near-total ban on private cryptocurrencies like Bitcoin or Ethereum, including owning the virtual currency. The government has discussed plans for a national digital currency as an alternative.',
#  'url': 'https://www.theverge.com/2021/3/15/22332677/india-cryptocurrency-trading-mining-possession-ban-law-report',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IdgNJaOIQBsN8QbQcH2MDU6sAUA=/0x243:2040x1311/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10432811/mdoying_180308_2373_0091still.jpg',
#  'publishedAt': '2021-03-15T22:25:02Z',
#  'content': 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sent = []

for article in headlines_btc["articles"]:
    try:
        text=article['content']
        date=article['publishedAt']
        sentiment=analyzer.polarity_scores(text)
        compound=sentiment['compound']
        pos=sentiment['pos']
        neu=sentiment['neu']
        neg=sentiment['neg']
        
        btc_sent.append({
            'text':text,
            'date':date,
            'compound':compound,
            'positive':pos,
            'negative':neg,
            'neutral':neu,
        })
    except AttributeError:
        pass

btc_df = pd.DataFrame(btc_sent)
cols = ['date', 'text', 'compound', 'positive', 'negative', 'neutral']
btc_df=btc_df[cols]
btc_df.head()
# Out:
#                    date                                               text  \
# 0  2021-03-24T08:10:09Z  The inevitable has happened: You can now purch...
# 1  2021-04-01T10:05:00Z  This story originally appeared on MarketBeatAs...
# 2  2021-03-31T14:00:00Z  Whether youre looking to make a larger investm...
# 3  2021-04-06T06:13:00Z  This article was translated from our Spanish e...
# 4  2021-04-08T11:00:00Z  Opinions expressed by Entrepreneur contributor...
#
#    compound  positive  negative  neutral
# 0    0.3182     0.065     0.000    0.935
# 1    0.6357     0.124     0.043    0.834
# 2    0.0772     0.039     0.000    0.961
# 3   -0.3400     0.000     0.070    0.930
# 4    0.0000     0.000     0.000    1.000

# %%
# Create the ethereum sentiment scores DataFrame
eth_sent = []

for article in headlines_eth["articles"]:
    try:
        text=article['content']
        date=article['publishedAt']
        sentiment=analyzer.polarity_scores(text)
        compound=sentiment['compound']
        pos=sentiment['pos']
        neu=sentiment['neu']
        neg=sentiment['neg']
        
        eth_sent.append({
            'text':text,
            'date':date,
            'compound':compound,
            'positive':pos,
            'negative':neg,
            'neutral':neu,
        })
    except AttributeError:
        pass

eth_df = pd.DataFrame(eth_sent)
cols = ['date', 'text', 'compound', 'positive', 'negative', 'neutral']
eth_df = eth_df[cols]
eth_df.head()
# Out:
#                    date                                               text  \
# 0  2021-03-15T22:25:02Z  One of the strictest crackdowns worldwide\r\nP...
# 1  2021-03-31T14:00:00Z  Whether youre looking to make a larger investm...
# 2  2021-03-15T13:51:11Z  Famed auction house Christies just sold its fi...
# 3  2021-04-08T13:00:00Z  Lately Ive taken greatly to this epaper tablet...
# 4  2021-03-29T15:46:35Z  Payment card network Visa has announced that t...
#
#    compound  positive  negative  neutral
# 0   -0.5574     0.000     0.110    0.890
# 1    0.0772     0.039     0.000    0.961
# 2    0.0000     0.000     0.000    1.000
# 3   -0.3041     0.094     0.145    0.761
# 4    0.0000     0.000     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#          compound   positive    negative     neutral
# count  100.000000  100.00000  100.000000  100.000000
# mean     0.147772    0.05978    0.024410    0.915810
# std      0.366833    0.06846    0.045813    0.079966
# min     -0.757900    0.00000    0.000000    0.660000
# 25%      0.000000    0.00000    0.000000    0.865000
# 50%      0.000000    0.04950    0.000000    0.929500
# 75%      0.445000    0.09225    0.039000    1.000000
# max      0.908000    0.34000    0.198000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.137317    0.065690    0.030640    0.903670
# std      0.401260    0.071525    0.051318    0.081532
# min     -0.910000    0.000000    0.000000    0.664000
# 25%     -0.057625    0.000000    0.000000    0.853250
# 50%      0.077200    0.056000    0.000000    0.920000
# 75%      0.458800    0.097000    0.062500    0.953500
# max      0.850600    0.270000    0.299000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: ETH
#
# Q: Which coin had the highest compound score?
#
# A: ETH
#
# Q. Which coin had the highest positive score?
#
# A: BTC

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    lemmatizer = WordNetLemmatizer()
    
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
# Create a new tokens column for bitcoin
btc_df['tokens'] = btc_df['text'].apply(tokenizer)
btc_df.head()
# Out:
#                    date                                               text  \
# 0  2021-03-24T08:10:09Z  The inevitable has happened: You can now purch...
# 1  2021-04-01T10:05:00Z  This story originally appeared on MarketBeatAs...
# 2  2021-03-31T14:00:00Z  Whether youre looking to make a larger investm...
# 3  2021-04-06T06:13:00Z  This article was translated from our Spanish e...
# 4  2021-04-08T11:00:00Z  Opinions expressed by Entrepreneur contributor...
#
#    compound  positive  negative  neutral  \
# 0    0.3182     0.065     0.000    0.935
# 1    0.6357     0.124     0.043    0.834
# 2    0.0772     0.039     0.000    0.961
# 3   -0.3400     0.000     0.070    0.930
# 4    0.0000     0.000     0.000    1.000
#
#                                               tokens
# 0  [inevitable, ha, happened, purchase, tesla, ve...
# 1  [story, originally, appeared, marketbeatas, cr...
# 2  [whether, youre, looking, make, larger, invest...
# 3  [article, wa, translated, spanish, edition, us...
# 4  [opinions, expressed, entrepreneur, contributo...

# %%
# Create a new tokens column for ethereum
eth_df['tokens'] = eth_df['text'].apply(tokenizer)
eth_df.head()
# Out:
#                    date                                               text  \
# 0  2021-03-15T22:25:02Z  One of the strictest crackdowns worldwide\r\nP...
# 1  2021-03-31T14:00:00Z  Whether youre looking to make a larger investm...
# 2  2021-03-15T13:51:11Z  Famed auction house Christies just sold its fi...
# 3  2021-04-08T13:00:00Z  Lately Ive taken greatly to this epaper tablet...
# 4  2021-03-29T15:46:35Z  Payment card network Visa has announced that t...
#
#    compound  positive  negative  neutral  \
# 0   -0.5574     0.000     0.110    0.890
# 1    0.0772     0.039     0.000    0.961
# 2    0.0000     0.000     0.000    1.000
# 3   -0.3041     0.094     0.145    0.761
# 4    0.0000     0.000     0.000    1.000
#
#                                               tokens
# 0  [one, strictest, crackdown, worldwidephoto, mi...
# 1  [whether, youre, looking, make, larger, invest...
# 2  [famed, auction, house, christies, sold, first...
# 3  [lately, ive, taken, greatly, epaper, tablet, ...
# 4  [payment, card, network, visa, ha, announced, ...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def bigram(tokens):
    bigrams = dict(ngrams(tokens, n=2))
    return bigrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_df['bigrams'] = btc_df['tokens'].apply(bigram)
btc_df.head()
# Out:
#                    date                                               text  \
# 0  2021-03-24T08:10:09Z  The inevitable has happened: You can now purch...
# 1  2021-04-01T10:05:00Z  This story originally appeared on MarketBeatAs...
# 2  2021-03-31T14:00:00Z  Whether youre looking to make a larger investm...
# 3  2021-04-06T06:13:00Z  This article was translated from our Spanish e...
# 4  2021-04-08T11:00:00Z  Opinions expressed by Entrepreneur contributor...
#
#    compound  positive  negative  neutral  \
# 0    0.3182     0.065     0.000    0.935
# 1    0.6357     0.124     0.043    0.834
# 2    0.0772     0.039     0.000    0.961
# 3   -0.3400     0.000     0.070    0.930
# 4    0.0000     0.000     0.000    1.000
#
#                                               tokens  \
# 0  [inevitable, ha, happened, purchase, tesla, ve...
# 1  [story, originally, appeared, marketbeatas, cr...
# 2  [whether, youre, looking, make, larger, invest...
# 3  [article, wa, translated, spanish, edition, us...
# 4  [opinions, expressed, entrepreneur, contributo...
#
#                                              bigrams
# 0  {'inevitable': 'ha', 'ha': 'happened', 'happen...
# 1  {'story': 'originally', 'originally': 'appeare...
# 2  {'whether': 'youre', 'youre': 'looking', 'look...
# 3  {'article': 'wa', 'wa': 'summer', 'translated'...
# 4  {'opinions': 'expressed', 'expressed': 'entrep...

# %%
# Generate the Ethereum N-grams where N=2
eth_df['bigrams'] = eth_df['tokens'].apply(bigram)
eth_df.head()
# Out:
#                    date                                               text  \
# 0  2021-03-15T22:25:02Z  One of the strictest crackdowns worldwide\r\nP...
# 1  2021-03-31T14:00:00Z  Whether youre looking to make a larger investm...
# 2  2021-03-15T13:51:11Z  Famed auction house Christies just sold its fi...
# 3  2021-04-08T13:00:00Z  Lately Ive taken greatly to this epaper tablet...
# 4  2021-03-29T15:46:35Z  Payment card network Visa has announced that t...
#
#    compound  positive  negative  neutral  \
# 0   -0.5574     0.000     0.110    0.890
# 1    0.0772     0.039     0.000    0.961
# 2    0.0000     0.000     0.000    1.000
# 3   -0.3041     0.094     0.145    0.761
# 4    0.0000     0.000     0.000    1.000
#
#                                               tokens  \
# 0  [one, strictest, crackdown, worldwidephoto, mi...
# 1  [whether, youre, looking, make, larger, invest...
# 2  [famed, auction, house, christies, sold, first...
# 3  [lately, ive, taken, greatly, epaper, tablet, ...
# 4  [payment, card, network, visa, ha, announced, ...
#
#                                              bigrams
# 0  {'one': 'strictest', 'strictest': 'crackdown',...
# 1  {'whether': 'youre', 'youre': 'looking', 'look...
# 2  {'famed': 'auction', 'auction': 'house', 'hous...
# 3  {'lately': 'ive', 'ive': 'taken', 'taken': 'gr...
# 4  {'payment': 'card', 'card': 'network', 'networ...

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(btc_df['tokens'].sum(), N=10)
# Out:
# [('char', 98),
#  ('bitcoin', 60),
#  ('reuters', 39),
#  ('ha', 27),
#  ('march', 17),
#  ('new', 16),
#  ('tesla', 15),
#  ('photo', 15),
#  ('cryptocurrency', 14),
#  ('wa', 13)]

# %%
# Get the top 10 words for Ethereum
token_count(eth_df['tokens'].sum(), N=10)
# Out:
# [('char', 97),
#  ('nft', 23),
#  ('digital', 21),
#  ('cryptocurrency', 20),
#  ('million', 18),
#  ('token', 18),
#  ('reuters', 17),
#  ('nonfungible', 15),
#  ('ethereum', 14),
#  ('ha', 14)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud()
img = wc.generate(btc_df['tokens'].sum())
plt.imshow(img)

# %%
# Generate the Ethereum word cloud
img2 = wc.generate(btc_df['tokens'].sum())
plt.imshow(img2)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.17.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
btc_text = btc_df['text'].sum()

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_text)

# Add a title to the document
btc_doc.user_data['title'] = 'Bitcoin NER'

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The inevitable has happened: You can now purchase a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vehicle with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>This is according to Tesla CEO, pardon, Technoking
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who tweeted it on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>You can now buy a Tesla … [+1648 chars]This story originally appeared on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MarketBeatAs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  crazy as it may sound, especially when looking at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (BTC) meteoric rise over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but we think there is a very strong case for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+3926 chars]Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars]This article was translated from our
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  edition using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Opinions expressed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Entrepreneur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of… [+7537 chars]Opinions expressed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Entrepreneur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The crypto market moves in waves.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  remains the undisputed blockchain industry leader, but as the major banks and investment fund… [+4681 chars]As it promised
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  now accepts payment in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's website and a tweet from CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . In a subsequent tweet,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that &quot;Bitcoin paid to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-h

# %%
# List all Entities
print([ent.text for ent in btc_doc.ents])
# Out:
# ['Tesla', 'Bitcoin', 'Elon Musk', 'Wednesday', 'MarketBeatAs', 'Bitcoin’s', 'the past year', 'Bitcoin', 'Bitcoin, Ethereum', 'Bitcoin Cash', 'Spanish', 'AI', 'Entrepreneur', 'the summer', 'Entrepreneur', 'Bitcoin', 'earlier this year', 'Tesla', 'Bitcoin', 'Tesla', 'Elon Musk', 'Musk', 'Tesla', 'March 26', 'Chipotle Mexican Grill', 'NYSE', 'CMG', '100,000', '100,000', 'National Burrito Day', 'April 1', 'Fidelity, Coinbase', 'Tuesday', 'earlier this year', 'roughly $1.5 billion', 'early February', 'SEC', 'Burrito Day', 'April Fools Day', 'this year', 'tomorrow', 'Pollo Loco', 'Photo', 'Michele Doying', 'India', 'Reuters', '+1656 chars]Fifteen years', 'Twitter', 'Jack Dorsey', 'first', 'nearly $3 million', 'NFT', 'Sina Estavi', 'Bridge', 'last years', 'Twitter', 'Graham Ivan Clark', 'Twitters', 'India', 'Reuters', 'a big year', 'Robinhood', 'today', 'Christine Brown', 'Robinhoods', 'Infection', 'a Remote Code Execution', '22, 2021', 'MarketBeat\r\n', '2021', 'millions', 'Funko', 'NFT', 'TokenWave', '23, 2021', 'Spanish', 'AI', 'Bitcoin', 'the United States', 'FD Funds Management LLC', 'Reuters', 'Bitcoin', 'U.S.', 'January 8, 2021', 'Dado Ru', 'Reuters', 'Bitcoin', 'U.S.', 'January 27, 2020', 'PayPal', 'Julian Satterthwaite', 'the Wall Street Journal', 'the Commodity Futures Trading Commission', 'Coinbase', '$6.5 million', 'Entrepreneur', 'Last year', 'the Great Depression', 'first', '11, 2021', 'Peter Schiff', 'Wednesday', 'NFT', 'Ethereum', 'more than $224 million', '2021', 'OpenSea', 'the first quarter of 2021', 'American', 'Coinbase', 'Coinbase', 'New White House Communications', 'Anthony Scaramucci', 'daily', 'the White House', 'Washington', 'U.S.', 'July 21, 2017', 'Jonathan Ernst', 'NEW YORK', 'Reu', 'Apple', 'Robbed Blind', 'Last month', 'Phillipe Christodoulou', 'Reuters', 'Bitcoin', 'March 15, 2021', 'WASHINGTON', 'Reuters', 'Dec. 8, 2017', 'Benoit Tessier/File Photo\r\n', 'LONDON', 'Reuters', 'Elon Musk', 'Tesla', 'Reuters', 'March 24', 'Reuters', 'Wednesday', 'Reuters', 'Morgan Stanley', 'San Diego', 'California', 'Sept. 24, 2013', 'Mike Blake\r\n', 'Reuters', 'Reuters', 'Bitcoin', 'March 15, 2021', 'Reuters', 'Reuters', 'LONDON', 'March 29', 'Reuters', 'one-week', 'Monday', 'as much as 4.5%', '58,300', 'above $61,000', 'earlier this month', 'Visa Inc', 'Reuters', 'April 6', 'Reuters', 'Hindenburg Research', 'Tuesday', 'Chinese', 'Ebang International Holdings Inc.', 'Ebang', 'Reuters', 'SkyBridge Capital', 'Anthony Scaramucci', 'Wednesday', 'first', 'two month', '2018', 'BTC', 'around $20,000', 'less than $6,000', 'today', 'Reuters', 'FILE', 'Tesla Inc', 'Elon Musk', 'China', 'Model 3', 'Shanghai', 'China', 'January 7, 2020', 'Aly Song/File', 'Reuters', 'Dec. 8, 2017', 'Benoit Tessier/Illustration/File Photo', 'Reuters', 'ZURICH', 'Reuters', 'The Swiss Financial Market Supervisory Authority', 'FINMA', 'Zug', 'Bitcoin Suisse AG', '2019', 'Reuters', 'ZURICH', 'March 17', 'Reuters', 'The Swiss Financial Market Supervisory Authority', 'FINMA', 'Zug', 'Bitcoin Suisse AG', '2019', 'Reuters', 'Bitcoin', 'January 8, 2021', 'Dado Ruvic/File Photo/File Photo', 'Reuters', 'around $60,000', 'Monday', 'U.S.', 'more than 4%', 'Wednesday', '60,000', 'Sellers', '60,000', 'Montana', 'Carolinas', 'New York City', 'ATM', '31', '2021Meltem', 'CoinShares', 'Azeem Azhar', 'Bitcoin', '15', 'Reuters', 'Montana', 'Carolinas', 'New York City', 'ATM', 'thousands', 'Apple', '12', 'French', 'Reuters', 'FILE', 'Goldman Sachs', 'the New York Stock Exchange', 'NYSE', 'New York', 'U.S.', 'April 17, 2018', 'Brendan McDe', 'US Department of Justice', 'Canada', 'Reuters', 'billions of dollars', '$4 trillion', 'Wednesday', 'three', '$1.5 billion', 'Reuters', 'Reuters', 'Hindenburg Research', 'Tuesday', 'Ebang International Holdings Inc', 'Chinese', 'American Express', 'Elon Musk', 'today', '22, 2021', 'Bitcoin', 'American Airlines', 'U.S.', '24, 2021', 'Spanish', 'AI', 'Elon Musk', 'a few weeks ago', '10, 2021', 'Spanish', 'AI', 'Bitcoin', '2020', 'this  ...

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the ethereum text together
eth_text = eth_df['text'].sum()

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_text)

# Add a title to the document
eth_doc.user_data['title'] = 'Ethereum NER'

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michele Doying
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is reportedly moving forward with a sweeping ban on cryptocurrencies. According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the countrys legislat… [+1656 chars]Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars]Famed auction house
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  just sold its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  purely digital piece of art for a whopping
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $69 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . For that price, the buyer got a digital file of a collage of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  images and a complex legac… [+12891 chars]Lately Ive taken greatly to this epaper tablet, the ReMarkable 2. Im not sure who sells it. Not
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Its slower and monochrome and less powerful than my
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , but somehow its duller, pape… [+3520 chars]Payment card network
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has announced that transactions can be settled using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USD Coin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (USDC), a stablecoin powered by the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  company to test the new capabi… [+2187 chars]The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>That’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>Opinions expressed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Entrepreneur
#     <span style="fon

# %%
# List all Entities
print([ent.text for ent in eth_doc.ents])
# Out:
# ['One', 'Photo', 'Michele Doying', 'India', 'Reuters', 'Bitcoin, Ethereum', 'Bitcoin Cash', 'Christies', 'first', '$69 million', '5,000', 'Apple', 'Amazon', 'iPad', 'Visa', 'USD Coin', 'Ethereum', 'Crypto.com', 'first', 'NFT', 'Ethereum', '19, 2021', 'Entrepreneur', 'Two', 'Ethereum', 'NFT', 'recent weeks', 'chars]MetaMask', 'one', 'Ethereum', 'September 2020', 'Entrepreneur', 'Bitcoin', 'about $5.7 million', 'a big year', 'Robinhood', 'today', 'Christine Brown', 'Robinhoods', 'above $2,700', 'Kraken', 'Kraken', 'Pete Humiston', 'NFT', 'Ethereum', 'more than $224 million', '2021', 'OpenSea', '35%', 'March', 'Kraken', 'Dado Ruvic', 'Reuters', 'above $2,700', '26, 2021', 'Spanish', 'AI', 'New York Times', 'daily', 'Segal', 'Burn Alpha', 'Mirror', '0.1', 'ETH', 'yesterday', 'evening', '25', 'ETH', 'millions of dollars', '1990', 'millions of dollars', '36.32', 'April 3', '90%', 'Fidelity, Coinbase', 'Tuesday', 'Tesla', 'Bitcoin', 'Elon Musk', 'Wednesday', 'ETH Zurich', 'Empa', 'hours', 'Beeple’s', '$69 million', 'NFT', '24', '24', 'Twin', 'NFT', 'Ethereum', 'roughly $128,392.56', 'Oracle Corp', 'San Francisco', 'Thursday', 'India', 'Reuters', 'Hirst', 'Chris Young', 'Superstar', 'Damien Hirst', 'Ethereum', 'Dado Ruvic', 'Reuters', 'Friday', '60,000.</li', 'Kings', 'Leon', 'more than $2 million', 'Getty Images', 'two', 'Monday', 'Monday', 'Grayscale Investments', 'Wednesday', 'five', '13', 'Entrepreneur', 'Decentralized', '2020s', "Last year's", '29', 'Reuters', 'Monday', 'four', 'Japanese', 'these days', 'NFT', 'Bitcoin', '$2 trillion', 'first', 'earlier this week', 'Bitcoin\xa0', 'millions', '30, 2021', 'Visa', 'PayPal', 'Reuters', 'Visa', 'yesterday', 'second', 'Friday', 'above $2,000', '+4.12%', 'nearly 7%', 'around $2,069', 'thousands', 'GeForce', '3060', 'February 25', 'Nvidia', 'around 50%', 'Huang', '2017', 'first', 'Deutsche Bank', 'Nomura', 'New Y', 'Checkout', 'US', 'the next few months', 'first', 'last Monday', '40,671', '$18.9 million', 'first', 'NFT', 'Polkadot', 'NFT', 'Reuters', 'LONDON', 'March 12', 'Reuters', '$70 million', 'Friday', 'Christies', 'Meta', 'Bitcoin', 'first', 'Reuters', 'LONDON', 'March 12', 'Reuters', '$70 million', 'Friday', 'Chri', 'Alex Ramirez-Mallis', '36', 'The Post', 'NFT', 'NFT', 'One Calendar Year of Record', 'Elon Musks', 'NFT', 'over one million dollars', 'NFT', 'Ethereum', 'Ethereum', 'Token', '6', '2017', 'James Martin', 'CNET', 'Monday', 'March 22', 'Reuters', 'Jack Dorsey', 'first', 'NFT', 'just over $2.9 million dollars', 'Monday', 'NFT', 'Reuters', 'Jack Dorsey', 'first', 'NFT', 'just over $2.9 million dollars', 'Monday', 'FILE', 'Jack Dorsey', 'Reuters', 'billions of dollars', 'chars]0.5%', '4/5', 'roughly 12%', '4/5', '35', 'Dogecoin', 'March 19', 'Reu', 'millions', '$5 million', 'NFT', 'NFT', 'these days', 'Pussy Riot', 'Nadya Tolokonnikova', 'one', 'tomorrow', 'Ijon Inton', 'Cabanatuan City', 'about 68 miles', 'Manila', 'Nueva Ecija', 'first', 'February of this year', '31, 2021', 'Spanish', 'AI', 'more than 4%', 'Wednesday', '60,000', 'Sellers', '60,000', 'second', '145bn', 'Bitcoins', '5', 'NFT', '3D', '18,000', 'last month', 'this month', 'as much as 70%', 'February', 'Bloomberg', 'first', 'Spanish', 'AI', 'Entrepreneur', 'the summer', 'the past few months', 'millions of dollars', 'NFT', 'Thomson Reuters Foundation', 'Rafael Yuste', 'New Yorks Columbia University', '13, 2021', 'Super Bowl', 'the Tampa Bay Buccaneers', 'Rob Gronkowski', 'NFT', 'this year', 'NFT', 'millions of dollars', 'Leon', 'night', 'GroeningPen', 'the last decade', 'U.S.', 'Fed', 'Updates', 'U.S.', 'afternoon', 'NEW YORK', 'April 6', 'Reuters', 'U.S.', 'two-week', 'chars]NEW YORK', 'Reuters', 'a record $4.5 billion', 'the first quarter', 'Terry Crewscertainly', 'NFL', 'Elon Musk', 'Tuesday', 'NFT', 'Tesla', 'Chris Precht', 'Precht', 'NFT', 'Google', 'NFT', 'NFT', 'Viktor Vaug', 'DeFi', 'Tokens', 'Ruslan Fazlulov', 'Getty Images\r\n', 'ETH-USD', '6,000', '16,000', '50%', 'Ryan Maloney', 'Beastly Ballers', ' ...
